# %% [markdown]
# https://github.com/prof-syed5/first_project

# %%
import pandas as pd

# %% [markdown]
# ## _**DATA LOAD**_

# %%
df=pd.read_csv('world_population.csv')
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.shape
# Out:
# (234, 17)

# %%
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.tail()
# Out:
#      Rank CCA3  Country/Territory   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El Aaiún    Africa           575986
# 231    46  YEM              Yemen     Sanaa      Asia         33696614
# 232    63  ZMB             Zambia    Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe    Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.sample()
# Out:
#      Rank CCA3 Country/Territory Capital Continent  2022 Population  \
# 167   143  QAT             Qatar    Doha      Asia          2695122
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 167          2760385          2414573          1713504           645937
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 167           441675           277450           118007       11586
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 167           232.6189       1.0026                         0.03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
df.describe(include="all")
# Out:
#               Rank CCA3 Country/Territory Capital Continent  2022 Population  \
# count   234.000000  234               234     234       234     2.340000e+02
# unique         NaN  234               234     234         6              NaN
# top            NaN  AFG       Afghanistan   Kabul    Africa              NaN
# freq           NaN    1                 1       1        57              NaN
# mean    117.500000  NaN               NaN     NaN       NaN     3.407441e+07
# std      67.694165  NaN               NaN     NaN       NaN     1.367664e+08
# min       1.000000  NaN               NaN     NaN       NaN     5.100000e+02
# 25%      59.250000  NaN               NaN     NaN       NaN     4.197385e+05
# 50%     117.500000  NaN               NaN     NaN       NaN     5.559944e+06
# 75%     175.750000  NaN               NaN     NaN       NaN     2.247650e+07
# max     234.000000  NaN               NaN     NaN       NaN     1.425887e+09
#
# ...

# %% [markdown]
# ## _**DATA CLEANING**_

# %%
df.isnull()
# Out:
#       Rank   CCA3  Country/Territory  Capital  Continent  2022 Population  \
# 0    False  False              False    False      False            False
# 1    False  False              False    False      False            False
# 2    False  False              False    False      False            False
# 3    False  False              False    False      False            False
# 4    False  False              False    False      False            False
# ..     ...    ...                ...      ...        ...              ...
# 229  False  False              False    False      False            False
# 230  False  False              False    False      False            False
# 231  False  False              False    False      False            False
# 232  False  False              False    False      False            False
# 233  False  False              False    False      False            False
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
df.dropna()
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df=df.drop(columns=["Capital"])
df
# Out:
#      Rank CCA3  Country/Territory Continent  2022 Population  2020 Population  \
# 0      36  AFG        Afghanistan      Asia         41128771         38972230
# 1     138  ALB            Albania    Europe          2842321          2866849
# 2      34  DZA            Algeria    Africa         44903225         43451666
# 3     213  ASM     American Samoa   Oceania            44273            46189
# 4     203  AND            Andorra    Europe            79824            77700
# ..    ...  ...                ...       ...              ...              ...
# 229   226  WLF  Wallis and Futuna   Oceania            11572            11655
# 230   172  ESH     Western Sahara    Africa           575986           556048
# 231    46  YEM              Yemen      Asia         33696614         32284046
# 232    63  ZMB             Zambia    Africa         20017675         18927715
# 233    74  ZWE           Zimbabwe    Africa         16320537         15669666
#
# ...

# %%
del df["Rank"]
df
# Out:
#     CCA3  Country/Territory Continent  2022 Population  2020 Population  \
# 0    AFG        Afghanistan      Asia         41128771         38972230
# 1    ALB            Albania    Europe          2842321          2866849
# 2    DZA            Algeria    Africa         44903225         43451666
# 3    ASM     American Samoa   Oceania            44273            46189
# 4    AND            Andorra    Europe            79824            77700
# ..   ...                ...       ...              ...              ...
# 229  WLF  Wallis and Futuna   Oceania            11572            11655
# 230  ESH     Western Sahara    Africa           575986           556048
# 231  YEM              Yemen      Asia         33696614         32284046
# 232  ZMB             Zambia    Africa         20017675         18927715
# 233  ZWE           Zimbabwe    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# ...

# %%
df.drop(["CCA3"],axis=1,inplace=True)
df
# Out:
#      Country/Territory Continent  2022 Population  2020 Population  \
# 0          Afghanistan      Asia         41128771         38972230
# 1              Albania    Europe          2842321          2866849
# 2              Algeria    Africa         44903225         43451666
# 3       American Samoa   Oceania            44273            46189
# 4              Andorra    Europe            79824            77700
# ..                 ...       ...              ...              ...
# 229  Wallis and Futuna   Oceania            11572            11655
# 230     Western Sahara    Africa           575986           556048
# 231              Yemen      Asia         33696614         32284046
# 232             Zambia    Africa         20017675         18927715
# 233           Zimbabwe    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 0           33753499         28189672         19542982         10694796
# ...

# %% [markdown]
# ## _**DATA MANIPULATION**_

# %%
df["Area (km²)"].mean()
# Out:
# 581449.3846153846

# %%
df["Area (km²)"].median()
# Out:
# 81199.5

# %%
df["Area (km²)"].mode()
# Out:
# 0    21
# Name: Area (km²), dtype: int64

# %% [markdown]
# ## _**DATA DUPLICATIONS**_

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of      Country/Territory Continent  2022 Population  2020 Population  \
# 0          Afghanistan      Asia         41128771         38972230
# 1              Albania    Europe          2842321          2866849
# 2              Algeria    Africa         44903225         43451666
# 3       American Samoa   Oceania            44273            46189
# 4              Andorra    Europe            79824            77700
# ..                 ...       ...              ...              ...
# 229  Wallis and Futuna   Oceania            11572            11655
# 230     Western Sahara    Africa           575986           556048
# 231              Yemen      Asia         33696614         32284046
# 232             Zambia    Africa         20017675         18927715
# 233           Zimbabwe    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Country/Territory Continent  2022 Population  2020 Population  \
# 0          Afghanistan      Asia         41128771         38972230
# 1              Albania    Europe          2842321          2866849
# 2              Algeria    Africa         44903225         43451666
# 3       American Samoa   Oceania            44273            46189
# 4              Andorra    Europe            79824            77700
# ..                 ...       ...              ...              ...
# 229  Wallis and Futuna   Oceania            11572            11655
# 230     Western Sahara    Africa           575986           556048
# 231              Yemen      Asia         33696614         32284046
# 232             Zambia    Africa         20017675         18927715
# 233           Zimbabwe    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# ...

# %% [markdown]
# ## _**CHANGE DATA TYPES**_

# %%
df['Area (km²)'] = df['Area (km²)'].astype(bool)
df.dtypes
# Out:
# Country/Territory               object
# Continent                       object
# 2022 Population                  int64
# 2020 Population                  int64
# 2015 Population                  int64
# 2010 Population                  int64
# 2000 Population                  int64
# 1990 Population                  int64
# 1980 Population                  int64
# 1970 Population                  int64
# Area (km²)                        bool
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %% [markdown]
# ## _**ADD NEW COLUMNS**_

# %%
df["new_col"]=df["Growth Rate"].mean()
df
# Out:
#      Country/Territory Continent  2022 Population  2020 Population  \
# 0          Afghanistan      Asia         41128771         38972230
# 1              Albania    Europe          2842321          2866849
# 2              Algeria    Africa         44903225         43451666
# 3       American Samoa   Oceania            44273            46189
# 4              Andorra    Europe            79824            77700
# ..                 ...       ...              ...              ...
# 229  Wallis and Futuna   Oceania            11572            11655
# 230     Western Sahara    Africa           575986           556048
# 231              Yemen      Asia         33696614         32284046
# 232             Zambia    Africa         20017675         18927715
# 233           Zimbabwe    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 0           33753499         28189672         19542982         10694796
# ...

# %% [markdown]
# ## _**REMOVE A COLUMN**_

# %%
df.drop(columns=["new_col"], inplace=True)
df
# Out:
#      Country/Territory Continent  2022 Population  2020 Population  \
# 0          Afghanistan      Asia         41128771         38972230
# 1              Albania    Europe          2842321          2866849
# 2              Algeria    Africa         44903225         43451666
# 3       American Samoa   Oceania            44273            46189
# 4              Andorra    Europe            79824            77700
# ..                 ...       ...              ...              ...
# 229  Wallis and Futuna   Oceania            11572            11655
# 230     Western Sahara    Africa           575986           556048
# 231              Yemen      Asia         33696614         32284046
# 232             Zambia    Africa         20017675         18927715
# 233           Zimbabwe    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 0           33753499         28189672         19542982         10694796
# ...

# %% [markdown]
# ## _**ADD NEW ROW**_

# %%
a = pd.DataFrame({'Growth Rate':804,
                  'Continent':804,
                    '2022 Population':'888.13'},
                     index=[0])
a
df=pd.concat([a,df])
df
# Out:
#      Growth Rate Continent 2022 Population  Country/Territory  \
# 0       804.0000       804          888.13                NaN
# 0         1.0257      Asia        41128771        Afghanistan
# 1         0.9957    Europe         2842321            Albania
# 2         1.0164    Africa        44903225            Algeria
# 3         0.9831   Oceania           44273     American Samoa
# ..           ...       ...             ...                ...
# 229       0.9953   Oceania           11572  Wallis and Futuna
# 230       1.0184    Africa          575986     Western Sahara
# 231       1.0217      Asia        33696614              Yemen
# 232       1.0280    Africa        20017675             Zambia
# 233       1.0204    Africa        16320537           Zimbabwe
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 0                NaN              NaN              NaN              NaN
# 0         38972230.0       33753499.0       28189672.0       19542982.0
# ...

# %% [markdown]
# ## _**REMOVE A ROW**_

# %%
df. drop(0,inplace=True)
df
# Out:
#      Growth Rate Continent 2022 Population  Country/Territory  \
# 1         0.9957    Europe         2842321            Albania
# 2         1.0164    Africa        44903225            Algeria
# 3         0.9831   Oceania           44273     American Samoa
# 4         1.0100    Europe           79824            Andorra
# 5         1.0315    Africa        35588987             Angola
# ..           ...       ...             ...                ...
# 229       0.9953   Oceania           11572  Wallis and Futuna
# 230       1.0184    Africa          575986     Western Sahara
# 231       1.0217      Asia        33696614              Yemen
# 232       1.0280    Africa        20017675             Zambia
# 233       1.0204    Africa        16320537           Zimbabwe
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 1          2866849.0        2882481.0        2913399.0        3182021.0
# 2         43451666.0       39543154.0       35856344.0       30774621.0
# ...

# %% [markdown]
# ## _**SPECIFIC DATA**_

# %%
df[4:6]
# Out:
#    Growth Rate      Continent 2022 Population Country/Territory  \
# 5       1.0315         Africa        35588987            Angola
# 6       1.0066  North America           15857          Anguilla
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 5       33428485.0       28127721.0       23364185.0       16394062.0
# 6          15585.0          14525.0          13172.0          11047.0
#
#    1990 Population  1980 Population  1970 Population Area (km²)  \
# 5       11828638.0        8330047.0        6029700.0       True
# 6           8316.0           6560.0           6283.0       True
#
#    Density (per km²)  World Population Percentage
# 5            28.5466                         0.45
# 6           174.2527                         0.00

# %%
df[3:5:2]
# Out:
#    Growth Rate Continent 2022 Population Country/Territory  2020 Population  \
# 4         1.01    Europe           79824           Andorra          77700.0
#
#    2015 Population  2010 Population  2000 Population  1990 Population  \
# 4          71746.0          71519.0          66097.0          53569.0
#
#    1980 Population  1970 Population Area (km²)  Density (per km²)  \
# 4          35611.0          19860.0       True           170.5641
#
#    World Population Percentage
# 4                          0.0

# %%
df[['Continent']][30:40]
# Out:
#         Continent
# 31         Africa
# 32         Africa
# 33           Asia
# 34         Africa
# 35  North America
# 36         Africa
# 37  North America
# 38         Africa
# 39         Africa
# 40  South America

# %% [markdown]
# ## _**DATA AGGREGATION**_

# %%
df.agg({"Growth Rate": ['sum', 'mean']})
# Out:
#       Growth Rate
# sum    235.215400
# mean     1.009508

# %%
df.groupby("Growth Rate")

# %%
df["Growth Rate"].value_counts()
# Out:
# Growth Rate
# 1.0038    4
# 1.0015    3
# 1.0108    3
# 1.0079    3
# 1.0058    3
#          ..
# 1.0218    1
# 1.0242    1
# 1.0037    1
# 1.0134    1
# 1.0280    1
# Name: count, Length: 180, dtype: int64

# %% [markdown]
# ## _**DATA FILTERING**_

# %%
df.describe(include="all").iloc[[0,10]]
# Out:
#        Growth Rate Continent  2022 Population Country/Territory  \
# count     233.0000       233            233.0               233
# max         1.0691       NaN              NaN               NaN
#
#        2020 Population  2015 Population  2010 Population  2000 Population  \
# count     2.330000e+02     2.330000e+02     2.330000e+02     2.330000e+02
# max       1.424930e+09     1.393715e+09     1.348191e+09     1.264099e+09
#
#        1990 Population  1980 Population  1970 Population Area (km²)  \
# count     2.330000e+02            233.0            233.0        233
# max       1.153704e+09      982372466.0      822534450.0        NaN
#
#        Density (per km²)  World Population Percentage
# count           233.0000                       233.00
# max           23172.2667                        17.88

# %%
df.describe(include="all").loc[["min","max"]]
# Out:
#      Growth Rate Continent  2022 Population Country/Territory  \
# min       0.9120       NaN              NaN               NaN
# max       1.0691       NaN              NaN               NaN
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# min     5.200000e+02     5.640000e+02     5.960000e+02     6.510000e+02
# max     1.424930e+09     1.393715e+09     1.348191e+09     1.264099e+09
#
#      1990 Population  1980 Population  1970 Population Area (km²)  \
# min     7.000000e+02            733.0            752.0        NaN
# max     1.153704e+09      982372466.0      822534450.0        NaN
#
#      Density (per km²)  World Population Percentage
# min             0.0261                         0.00
# max         23172.2667                        17.88

# %% [markdown]
# ## _**FLOW CHARTS**_

# %%
df["Continent"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df["Continent"].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Continent"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Continent"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## _**STATISTICAL ANALYSIS**_

# %%
df["Density (per km²)"].mean()
# Out:
# 453.79686480686695

# %%
df["Density (per km²)"].median()
# Out:
# 96.7026

# %%
df["Density (per km²)"].mode()
# Out:
# 0          0.0261
# 1          0.3105
# 2          2.1654
# 3          2.1727
# 4          3.1092
#           ...
# 228     5441.5000
# 229     6783.3922
# 230     8416.4634
# 231    18234.5000
# 232    23172.2667
# Name: Density (per km²), Length: 233, dtype: float64

# %%
df["Density (per km²)"].min()
# Out:
# 0.0261

# %%
df["Density (per km²)"].max()
# Out:
# 23172.2667

# %%
df["Density (per km²)"].std()
# Out:
# 2070.411723004147

# %% [markdown]
# ## _**SAVE DATA**_

# %%
df=pd.read_csv("world_population.csv")
df
df.to_excel("new_project.xlsx", sheet_name="secsheet")
